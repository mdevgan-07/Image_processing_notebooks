# %% [markdown]
# WAP to convert a Grayscale Image into a Binary Image

# %%
#case 1: Assume mean intesnsity image as the threshold image

import cv2
import numpy as np
from google.colab.patches import cv2_imshow

img=cv2.imread('/content/grayscale_img.jpg',cv2.IMREAD_GRAYSCALE)
cv2_imshow(img)
mean_threshold=int(np.mean(img))
binary_img=cv2.threshold(img,mean_threshold,255,cv2.THRESH_BINARY)[1]

print("Mean threshold used: {mean_threhold}")
cv2_imshow(binary_img)

# %%
#case 2: Input the threshold value from the user
img=cv2.imread('/content/grayscale_img.jpg',cv2.IMREAD_GRAYSCALE)
cv2_imshow(img)

user_threshold=int(input("Enter the threhold value:(0-255): "))
binary_img=cv2.threshold(img,user_threshold,255,cv2.THRESH_BINARY)[1]
cv2_imshow(binary_img)
